# %% [markdown]
# <a href="https://colab.research.google.com/github/HamedFarahani89/Quantum-Computing-Lab/blob/main/Expectation_Value_of_the_Pauli_Z.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 📌 Expectation Value of the Pauli-Z Operator in PennyLane
#
# In **quantum computing**, the expectation value of an operator provides insights into the measured outcomes of a quantum state. The **Pauli-Z operator** is one of the fundamental Pauli matrices used for measuring qubit states.
#
# ## 🧮 Definition of the Pauli-Z Operator
# The **Pauli-Z** matrix in the standard basis $\{|0\rangle, |1\rangle\} $ is:
#
# $
# Z =
# \begin{bmatrix}
# 1 & 0 \\
# 0 & -1
# \end{bmatrix}
# $
#
# The expectation value of $ Z $ for a quantum state $ |\psi\rangle $ is:
#
# $
# \langle Z \rangle = \langle \psi | Z | \psi \rangle
# $

# %%
! pip install pennylane
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.1/56.1 kB 3.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 40.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 930.8/930.8 kB 36.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 53.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 55.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.9/167.9 kB 12.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 53.1 MB/s eta 0:00:00
# ...

# %%
import pennylane as qml

dev = qml.device("default.qubit", wires=1)

@qml.qnode(dev)
def circuit():
    return qml.expval(qml.PauliZ(0))

print(circuit())
# Out:
# 1.0

# %%
dev = qml.device("default.qubit", wires=1)

@qml.qnode(dev)
def circuit():
    qml.PauliX(0)
    return qml.expval(qml.PauliZ(0))

print(circuit())
# Out:
# -1.0

# %%
dev = qml.device("default.qubit", wires=1)

@qml.qnode(dev)
def circuit():
    qml.Hadamard(0)
    return qml.expval(qml.PauliZ(0))

print(circuit())
# Out:
# 0.0

# %%
from IPython.display import Image
Image(filename='cal.png')
